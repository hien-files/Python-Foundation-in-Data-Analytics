# %% [markdown]
# # VISUALIZING WITH MATPLOTLIB AND PANDAS .plot()
# <img src = "https://matplotlib.org/_static/logo2.png" alt = "matplotlib" width = "50%"/>

# %% [markdown]
# Matplotlib is a package for data visualization in Python. The library is built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# One of Matplotlib’s most important features is its **ability to play well with many operating systems and graphics backends**. Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish. This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# Matplotlib is  designed to help users to visualize data as easily as possible, with all the necessary control -- that is, by using relatively high-level commands most of the time, and still have the ability to use the low-level commands when needed.
#
# Therefore, everything in matplotlib is organized in a hierarchy. At the top of the hierarchy is the matplotlib "state-machine environment" which is provided by the [`matplotlib.pyplot`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot) module. At this level, simple functions are used to add plot elements (lines, images, text, etc.) to the current axes in the current figure.

# %% [markdown]
# **COMPONENTS OF A FIGURE**
#
# <img src = 'https://i.imgur.com/AaqxaKy.png' width = 600>
#
# <img src = "https://matplotlib.org/_images/anatomy.png" alt = "drawing" width = "600">

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# `matplotlib.pyplot` is a collection of command style functions that make matplotlib work like **MATLAB**. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %% [markdown]
# ## 1. FIGURE AND SUBPLOTS

# %% [markdown]
# ### Create figure and subplots
#
# 👉 To create figure and subplots:
#
# ```plt.figure()``` ▸ https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
#
# ```plt.subplot()``` ▸ https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html

# %% [markdown]
# There is nothing there because we haven't plot anything. Let's load the data and try plotting something.

# %%
df = pd.read_csv('data\\restaurant.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# PLOT NUMBER OF BILLS BY DAY
sns.countplot(data = df,
              x = 'day')
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
plt.figure(figsize = (10, 4)) # rộng - cao theo inches (max 30)
sns.countplot(data = df,
              x = 'day')
plt.show()

# %% [markdown]
# ***MULTIPLE SUBPLOTS IN ONE FIGURE***
#
# `plt.subplot(numberOfRow, numberOfColumn, Position)`

# %% [markdown]
# <img src = "https://qiita-image-store.s3.ap-northeast-1.amazonaws.com/0/118901/b5751bb2-c6f8-27ec-11ad-f538892d0664.png" width = "500">
#
# In order to adjust in subplots:
# ```python
# plt.subplots_adjust(
#     left    = <Number>,
#     bottom  = <Number>,
#     right   = <Number>,
#     top     = <Number>,
#     wspace  = <Number>,
#     hspace  = <Number>
# )
# ```

# %%
plt.figure(figsize = (20, 6)) # rộng - cao theo inches (max 30)

plt.subplot(1, 2, 1)
sns.countplot(data = df,
              x = 'day')

plt.subplot(1, 2, 2)
sns.histplot(data = df,
              x = 'tip')
              
# Adjust sub plot
# plt.subplots_adjust(wspace = 0.1)
plt.show()

# %%
plt.figure(figsize = (20, 6)) # rộng - cao theo inches (max 30)

plt.subplot(3, 2, 1)
sns.countplot(data = df,
              x = 'day')

plt.subplot(3,2, 6)
sns.histplot(data = df,
              x = 'tip')
plt.show()

# %% [markdown]
# 👉 **TASK: Create a new graph with 4 subplot that show:**
#
# - Number of bills by day
# - Number of bills by time
# - Number of bills by gender
# - Number of bills by table size
#
# EXPECTED OUTPUT:
# <img src = "https://i.imgur.com/2ZRxk5b.png">

# %%
# YOUR CODE HERE

# %% [markdown]
# 👉 **Using For loop to plot charts**

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Select categories columns
cate_cols = ['sex', 'smoker', 'day', 'time']

plt.figure(figsize = (10, 6))
for i, col_name in enumerate(cate_cols):
    plt.subplot(2, 2, i+1)
    sns.countplot(
        data = df,
        x = col_name
    )
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Adding titles
#
# Now that we have all the graphs needed. Let's give it a name.
#
# 👉 To add title:
#
# ```plt.suptitle()``` ▸ https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.suptitle.html
#
# ```plt.title()``` ▸ https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.title.html

# %%
plt.figure(figsize = (20, 6)) # rộng - cao theo inches (max 30)

# draw subplot 1
plt.subplot(121)
sns.countplot(data = df,
              x = 'day')

# draw subplot 2
plt.subplot(122)
sns.histplot(data = df,
              x = 'tip')

# Set title for dashboard:
plt.suptitle('RESTAURANT ANALYSIS', fontsize = 20, color = 'red')
plt.show()

# %%
plt.figure(figsize = (20, 6)) # rộng - cao theo inches (max 30)

# draw subplot 1
plt.subplot(121)
sns.countplot(data = df,
              x = 'day')
# Set title for subplot 1
plt.title('NUMBER OF TRANSACTION BY DAYS', loc = 'left')


# draw subplot 2
plt.subplot(122)
sns.histplot(data = df,
              x = 'tip')
# Set title for subplot 2
plt.title('NUMBER OF TRANSACTION BY TIP AMOUNT', color = 'green', fontsize = 15)

# Set title for dashboard:
plt.suptitle('RESTAURANT ANALYSIS', fontsize = 20, color = 'red')
plt.show()

# %% [markdown]
# ## 2. FORMATTING AXIS & STYLING

# %% [markdown]
# Let's go back to our simple plot.

# %%
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')
plt.show()

# %% [markdown]
# ### plt.xlabel / plt.ylabel

# %% [markdown]
# You can use the syntax to simply change the name of the axis.

# %%
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')
plt.xlabel("Days of Week")
plt.ylabel("Number of bill")
plt.show()

# %% [markdown]
# ### plt.xticks / plt.yticks

# %%
plt.figure(figsize = (5,5))
sns.histplot(data = df,
             x = 'total_bill')
plt.show()

# %% [markdown]
# Working with continuous axis:

# %%
plt.figure(figsize = (5,3))
sns.histplot(data = df,
             x = 'total_bill')
plt.xticks(ticks = [0, 5, 6, 7, 8, 10, 15, 20]) #Tell them which tick position do you want to display?
plt.show()

# %% [markdown]
# **Rotation xticks**

# %%
plt.figure(figsize = (5,5))
sns.histplot(data = df,
             x = 'total_bill')
plt.xticks(ticks = [0, 5, 8, 10, 15, 20, 50, 80], rotation = 60) #Tell them which tick position do you want to display?
plt.show()

# %% [markdown]
# Working with categorical axis:

# %%
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])

# Using plt.xticks or plt.yticks to change the ticks
plt.xticks(ticks = [0, 2, 3],
           labels = ['Thursday', 'Saturday', 'Sunday'])

plt.show()

# %% [markdown]
# ### plt.xlim / plt.ylim

# %%
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])

# Using plt.ylim to limit or expand the range of the y axis.
plt.ylim(0, 200)
plt.show()

# %% [markdown]
# 🙋🏻‍♂️ **TASK: Draw a histogram that shows the distribution of total bill but limit the total bill only to the range from 10 to 40**

# %%
# YOUR CODE HERE
plt.figure(figsize = (7, 5))
sns.histplot(data = df,
             x = 'total_bill')
# What should I write here?
# your code here

plt.show()

# %% [markdown]
# **How should I finish the above code?**
#
# A. plt.xticks(10, 40)
#
# B. plt.yticks(10, 40)
#
# C. plt.xlim(10, 40)
#
# D. plt.ylim(10, 40)

# %%
# Limit on categorical axis
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])
# 👉 just show fri and sat:
plt.xlim(0.5, 2.5)

plt.show()

# %% [markdown]
# ### plt.twinx() ▸ Shared Axis

# %% [markdown]
# Example: Create a shared axis plot with:
# - A countplot of number of bills by day
# - A lineplot of average amount of tip by day.

# %%
plot_data = df.groupby('day')['tip'].mean().reset_index()
plot_data
# Out:
#     day       tip
# 0   Fri  2.734737
# 1   Sat  2.993103
# 2   Sun  3.255132
# 3  Thur  2.771452

# %%
plt.figure(figsize = (6, 6))
sns.countplot(data = df,
              x = 'day')
plt.ylabel('Number of bills')
plt.ylim(0, 150)

plt.twinx() # share x axis

sns.lineplot(data = plot_data,
             x = 'day',
             y = 'tip')
plt.ylabel('Average Tip')
plt.ylim(-1,4)
plt.yticks(range(0,5,1))
plt.suptitle('TOTAL BILLS AND AVERAGE TIP BY DAYS', fontsize = 15, color = 'blue')
plt.show()

# %% [markdown]
# ### Styling

# %% [markdown]
# There are many styles that you can try to stylize your report. Please refer to this documentation: https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html
#
# <img src = "https://i.ibb.co/zZWF37Q/Screenshot-2022-12-14-221854.png" width = "800">

# %%
# Set up the theme
plt.style.use('default')

plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')

plt.show()

# %%
# Set up the theme
plt.style.use('bmh')

plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')

plt.show()

# %%
# Set up the theme
plt.style.use('ggplot')

plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')

plt.show()

# %% [markdown]
# ## 3. ADDING TEXT

# %% [markdown]
# ```plt.text( )``` ▸ https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html
#
# Some important parameters:
#
# - `x`: x location
# - `y`: y location
# - `s`: message in string
# - `horizontal alignment` or `ha`: "center", "right", or "left"
# - `fontsize`: font size
# - Furthermore, any other formatting parameter can be passed in as a dictionary. Please refer in the link.

# %%
plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')
plt.text(x = 0, 
         y = 80, 
         s = "This is a string", 
         ha = 'center', 
         color = 'black', 
         fontsize = 13)
plt.show()

# %%
# Organize style vào dictionary 
font_dict = {'color':'green', 'fontsize': 17, 'ha': 'center'}

plt.figure(figsize = (3, 3))
sns.countplot(data = df,
              x = 'day')
plt.text(x = 0, 
         y = 80, 
         s = "This is a string", 
         fontdict = font_dict)
plt.show()

# %% [markdown]
# 🙋🏻‍♂️ **TASK: Find a way to put the value of each bar on top of the bar.**

# %%
plot_data = df.groupby('day')['size'].count().loc[['Thur', 'Fri', 'Sat', 'Sun']].reset_index()
plot_data
# Out:
#     day  size
# 0  Thur    62
# 1   Fri    19
# 2   Sat    87
# 3   Sun    76

# %%
plt.figure(figsize = (4, 4))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])

plt.show()

# %%
# Show data values:
plt.figure(figsize = (4, 4))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])

for i in range(plot_data.shape[0]):
    plt.text(
        x = i, 
        y = plot_data['size'][i] + 1, 
        s = plot_data['size'][i],
        ha = 'center')

plt.show()

# %% [markdown]
# ## 4. ADDING LINE

# %%
plt.figure(figsize = (8, 6))
sns.countplot(data = df,
              x = 'day',
              order = ['Thur', 'Fri', 'Sat', 'Sun'])

for i in range(plot_data.shape[0]):
    plt.text(
        x = i, 
        y = plot_data['size'][i] + 1, 
        s = plot_data['size'][i],
        ha = 'center')
# Add a horizontal line:
plt.axhline(67, color = 'green')

# Add a vertical line:
plt.axvline(2.5, color = 'green')

plt.show()

# %% [markdown]
# ## 5. PANDAS BUILT-IN PLOT FUNCTION .plot( )

# %% [markdown]
# **When is it useful?**
#
# ☀︎ Quick visualization. I mean, QUICK!
#
# ☀︎ Line plot with time series data.
#
# ☀︎ Stacked bar, stacked area, stacked histogram.
#
# **How to do it?** ▸ Simply get the plot table and call ```.plot()``` with ```kind = ``` to specify the kind of chart.
#
# *DataFrame*`.plot(*args, **kwargs)`
# ```
# Parameters:
# data:   Series or DataFrame
#         The object for which the method is called.
#
# x:      label or position, default None
#         Only used if data is a DataFrame.
#
# y:      label, position or list of label, positions, default None
#         Allows plotting of one column versus another. Only used if data is a DataFrame.
# kind:   str, The kind of plot to produce:
#             ‘line’ : line plot (default)
#             ‘bar’ : vertical bar plot
#             ‘barh’ : horizontal bar plot
#             ‘hist’ : histogram
#             ‘box’ : boxplot
#             ‘kde’ : Kernel Density Estimation plot
#             ‘density’ : same as ‘kde’
#             ‘area’ : area plot
#             ‘pie’ : pie plot
#             ‘scatter’ : scatter plot (DataFrame only)
#             ‘hexbin’ : hexbin plot (DataFrame only)
# figsize: a tuple (width, height) in inches, Size of a figure object.
# title:  Chart's title
# ```
#
# When creating the ```plot_data``` table for plotting:
#
# ❗️ **The axis dimension must be index of the plot_data table**.
#
# Official Documentation ▸ https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
#
# Guide ▸ https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# Guide ▸ https://realpython.com/pandas-plot-python/

# %%
df = pd.read_csv('data\\restaurant.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Example 1: Distribution of the column total bill

# %%
# Histogram
df['total_bill'].plot(kind = 'hist', color = 'red', figsize = (4,4))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Boxplot
df['total_bill'].plot(kind = 'box', figsize = (4,4))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Example 2: Average total_bill by day.
#
# Plot data can be computed from a groupby method.

# %%
df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
# Trung bình Totalbill theo  ngày:
df.groupby('day')['total_bill'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='day'>

# %%
# Barh: # Trung bình Totalbill theo  ngày:
df.groupby('day')['total_bill'].sum().plot(kind = 'barh')

# %%
# 👉 Your turn: Vẽ biểu đồ đường thể hiện Trung bình số tiền tip theo day
# Your code here:

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# Pie chart
df['day'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot: ylabel='day'>

# %% [markdown]
# ## SUMMARY
#
# ▸ **MATPLOTLIB**
#
# ```python
# # Import matplotlib
# import matplotlib.pyplot as plt
#
# ------ FIGURE AND SUBPLOT -------
#
# # Create a figure with size of 10 inches x 10 inches
# plt.figure(figsize = (10, 10))
#
# # Create a subplot at the first position in a grid of 1 row, 2 columns
# plt.subplot(121)
#
# # Create a subplot at the fourth position in a grid of 2 row, 3 columns
# plt.subplot(234)
#
# # Name the figure
# plt.suptitle("Name")
#
# # Name the subplot
# plt.title("Name")
#
#
# ------ FORMATTING AND STYLING -------
# # Change axis name
# plt.xlabel("Name")
# plt.ylabel("Name")
#
# # Change x_axis ticks at the position 0, 2, 3 to new name "A", "B", "C"
# plt.xticks(ticks = [0, 2, 3],
#            labels = ['A', 'B', 'C'])
#
# # Change the limit of y axis to 20 to 40
# plt.ylim(20, 40)
#
# # Create a shared axis chart
# plt.twinx()
#
# # Change plotting theme
# plt.style.use('theme_name')
#
# ------ A SAMPLE CODE BLOCK -------
# # Visualize a shared axis chart with
# # Countplot of number of bills by day
# # And a lineplot of average tip by day
#
#
# # Step 1: Prepare the data for the average tip by day
# plot_data = df.groupby('day')['tip'].mean().reset_index()
#
# # Step 2: Plot
# plt.figure(figisize = (10, 10))
# sns.countplot(data = df,
#               x = 'day')
# plt.twinx()
# sns.lineplot(data = df,
#              x = 'day',
#              y = 'tip')
# plt.show()
# ```
#
# ▸ .PLOT( )
#
# ```python
# # Example: plot a stacked bar from a table name "commerce".
# commerce.plot(kind = 'bar',
#               stacked = True,
#               figsize = (10,10),
#               color = 'blue')
# ```
#
# ❗️ What you want to be the dimensions of your chart MUST BE the index of the table.
