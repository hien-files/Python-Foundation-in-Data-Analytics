# %% [markdown]
# # Linear Regression Project
#
# Congratulations! You just got some contract work with an Ecommerce company based in New York City that sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
#
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They've hired you on contract to help them figure it out! Let's get started!
#
# Just follow the steps below to analyze the customer data (it's fake, don't worry I didn't give you real credit card numbers or emails).

# %% [markdown]
# ## Pearson Correlation Coefficient

# %% [markdown]
# <img src="https://statsmethods.files.wordpress.com/2013/05/correlationcoefficient.png" width="600">

# %% [markdown]
# - `The correlation coefficient` is a statistical `measure` of the `strength of a linear relationship between two variables`.
# - Its values can `range` from `-1 to 1.` A correlation coefficient of -1 describes a perfect negative, or inverse, correlation, with values in one series rising as those in the other decline, and vice versa.
# - A coefficient of 1 shows a perfect positive correlation, or a direct relationship.
# - A correlation coefficient of 0 means there is no linear relationship.
#
# <img src="https://www.alpharithms.com/wp-content/uploads/1074/simplified-correlation-coefficient-formula-vs-expanded.jpg" width="400">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'Experience': [1, 2, 3, 4, 5, 6, 7, 8, 9],
        'Salary': [100, 120, 200, 250, 255, 400, 1000, 1050, 1800],
        'low_class_ratio': [0.9, 0.78, 0.7, 0.66, 0.5, 0.47, 0.2, 0.05, 0.03]        
}
df = pd.DataFrame(data)
df
# Out:
#    Experience  Salary  low_class_ratio
# 0           1     100             0.90
# 1           2     120             0.78
# 2           3     200             0.70
# 3           4     250             0.66
# 4           5     255             0.50
# 5           6     400             0.47
# 6           7    1000             0.20
# 7           8    1050             0.05
# 8           9    1800             0.03

# %%
# Calculate correlation coefficient of those numeric columns:
sns.heatmap( df.corr(), cmap= 'YlGnBu', annot=True )
plt.show()

# %%
# Using Numpy to Calculate correlation between 2 columns:
np.corrcoef(df['Experience'], df['low_class_ratio'])
# Out:
# array([[ 1.       , -0.9819659],
#        [-0.9819659,  1.       ]])

# %%
# Using Numpy to Calculate correlation between 2 columns:
np.corrcoef(df['Experience'], df['low_class_ratio'])[1, 0]
# Out:
# -0.9819658996688476

# %% [markdown]
# ## Imports
# **Import pandas, numpy, matplotlib,and seaborn**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Get the Data
#
# We'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas Email, Address, and their color Avatar. Then it also has numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.
#
# **Read in the Ecommerce Customers csv file as a DataFrame called customers.**

# %%
customers_org = pd.read_csv("data\\Ecommerce Customers.csv")

# %% [markdown]
# **Check the head of customers, and check out its info() and describe() methods.**

# %%
# Describe dataset:
# # Your code here

# %%
# Get info() of dataset:
# Your code here

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Let's explore the data!**
#
# For the rest of the exercise we'll only be using the numerical data of the csv file.

# %%
# Get all float-type columns:
numerical_cols = [c for c in customers_org.columns if customers_org[c].dtype == 'float']
numerical_cols
# Out:
# ['Avg. Session Length',
#  'Time on App',
#  'Time on Website',
#  'Length of Membership',
#  'Yearly Amount Spent']

# %%
# Just select those numerical columns:
customers = customers_org[numerical_cols]
customers.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %% [markdown]
# 👉 Use seaborn to create a **regplot** to compare the **Time on Website** and **Yearly Amount Spent** columns. Does the correlation make sense? (with Confidence Interval = 95%)

# %%
# Your code here 
sns.regplot(
    x = ___ ,
    y = ___,
    data = ___, 
    ci = 95)
plt.show()

# %% [markdown]
# 👉 Do the same but with the **Time on App** column instead.

# %%
# Your code here
# Out:
# <AxesSubplot: xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %% [markdown]
# 👉 **Let's explore these types of relationships across the entire data set. Use [pairplot](https://stanford.edu/~mwaskom/software/seaborn/tutorial/axis_grids.html#plotting-pairwise-relationships-with-pairgrid-and-pairplot) to recreate the plot below.(Don't worry about the the colors)**

# %%
# Your code here

# %% [markdown]
# 👉 **Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**

# %%
# Your answer here:

# %% [markdown]
# 👉 Create a regplot (using seaborn) of  **Yearly Amount Spent** vs. **Length of Membership**.

# %%
# Your code here

# %% [markdown]
# 👉 let's take a look on detail of correlation of each features: (using **.corr()**)

# %%
# Visualizing the data using heatmap
sns.heatmap(___.corr() # Your code here,
             cmap="YlGnBu", 
             annot = True)
plt.show()

# %% [markdown]
# ## Training and Testing Data
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
#
# Set a variable **X equal to the numerical features** of the customers and a variable y equal to the **"Yearly Amount Spent"** column with **assumtion that there is a linear relationship between them**

# %%
# Assign label to y:
# Your code here

# %%
# Assign features to X:
# Your code here

# %% [markdown]
# **Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
# Import train_test_split from sklearn:

# %%
X_train, X_test, y_train, y_test = train_test_split(___ # Your code here )

print('X train shape:', X_train.shape)
print('y train shape:', y_train.shape)
print('X test shape:', X_test.shape)
print('X test shape:', y_test.shape)
# Out:
# X train shape: (350, 4)
# y train shape: (350,)
# X test shape: (150, 4)
# X test shape: (150,)

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import LinearRegression from sklearn.linear_model **

# %%
# 👉 Import  LinearRegression model

# %% [markdown]
# **Create an instance of a LinearRegression() model named lm.**

# %%
lm = ___ # Your code here

# %% [markdown]
# **Train/fit lm on the training data.**

# %%
# Your code here :
# Out:
# LinearRegression()

# %% [markdown]
# Print out the **coefficients** and **bias** of the model

# %%
# The coefficients
print(f'Coefficients: {___ # Your code here }')

print(f'Bias (Intercept): {___ # Your code here }')
# Out:
# Coefficients: [25.98154972 38.59015875  0.19040528 61.27909654]
# Bias: -1047.9327822502391

# %% [markdown]
# 👉 **Double click on this cell and fill-in suitable numbers to the blanks (___):**
#
# Model formular:
#
# `y` = ___ * `'Avg. Session Length'` + ___ * `'Time on App'` + ___ * `'Time on Website'` + ___ * `'Length of Membership'` + ___

# %%
# Predict on training data:
y_train_pred = ___ # Your code here

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# **Use lm.predict() to predict off the X_test set of the data.**

# %%
y_test_pred = ___ # Your code here

# %% [markdown]
# ** Create a scatterplot of the real test values versus the predicted values. **

# %%
plt.scatter(y_test, y_test_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %% [markdown]
# ## Evaluating the Model
#
# **Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error. Refer to the lecture or to Wikipedia for the formulas**

# %%
# calculate these metrics by hand!
from sklearn.metrics import mean_absolute_error, mean_squared_error

print('Evaluate on Trainset:')
print('MAE:', mean_absolute_error( ___ # Your code here ))
print('MSE:', ___ # Your code here )
print('RMSE:', np.sqrt( ___ # Your code here ))

print('=='*30)

print('Evaluate on Testset:')
print('MAE:', mean_absolute_error( ___ # Your code here ))
print('MSE:', ___ # Your code here )
print('RMSE:', np.sqrt( ___ # Your code here ))
# Out:
# Evaluate on Trainset:
# MAE: 8.181347287342842
# MSE: 106.85137432285724
# RMSE: 10.336893843068005
# ...
# Evaluate on Testset:
# MAE: 7.228148653430811
# MSE: 79.81305165097385
# RMSE: 8.9338150669786

# %% [markdown]
# 👉 In practice, when we do comparing performance of serveral machine learning models, we should select the one with ___ loss function:
#
# + A. Lower
# + B. Higher
# + C. Approximate to 0 most
# + D. Approximate to 100 most

# %%
# Your answer here:

# %% [markdown]
# ## Conclusion
# We still want to figure out the answer to the original question, do we focus our efforst on mobile app or website development? Or maybe that doesn't even really matter, and Membership Time is what is really important.  Let's see if we can interpret the coefficients at all to get an idea.
#
# ** Recreate the dataframe below. **

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                       Coeffecient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097

# %% [markdown]
# **👉 How can you interpret these coefficients?** *Fill-in the blanks (___) with 2 decimals round*

# %% [markdown]
# Interpreting the coefficients:
#
# - Holding all other features fixed, a 1 unit increase in **Avg. Session Length** is associated with an **increase of `___` total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Time on App** is associated with an **increase of `___` total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Time on Website** is associated with an **increase of `___` total dollars spent**.
# - Holding all other features fixed, a 1 unit increase in **Length of Membership** is associated with an **increase of `___` total dollars spent**.

# %% [markdown]
# **🤔 Do you think the company should focus more on their mobile app or on their website?**

# %%
# Your answer here:

# %% [markdown]
# ## Great Job!
#
# Congrats on your contract work! The company loved the insights! Let's move on.
